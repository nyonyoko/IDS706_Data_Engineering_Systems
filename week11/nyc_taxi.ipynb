# %% [markdown]
# # NYC Taxi PySpark Pipeline (Databricks)
# *Dataset:* `/databricks-datasets/nyctaxi/` (yellow tripdata + taxi zone lookup)
#
# This notebook implements:
# - Data loading (>1GB)
# - Apply transformations:
#     - 2+ filter operations
#     - complex aggregation
#     - 1+ groupBy with aggregations
#     - Column transformations using withColumn
# - 2+ SQL queries
# - Optimization: filter pushdown, partitioning, avoiding shuffles, caching
# - Write results to Parquet
# - Actions vs Transformations
# - MLlib model

# %% [markdown]
# # Load data

# %%
# Setup: inspect dataset structure
display(dbutils.fs.ls("/databricks-datasets/nyctaxi"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/nyctaxi/readme_nyctaxi.txt</td><td>readme_nyctaxi.txt</td><td>916</td><td>1596568072000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/reference/</td><td>reference/</td><td>0</td><td>1762914946558</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/sample/</td><td>sample/</td><td>0</td><td>1762914946558</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tables/</td><td>tables/</td><td>0</td><td>1762914946558</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/taxizone/</td><td>taxizone/</td><td>0</td><td>1762914946558</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/</td><td>tripdata/</td><td>0</td><td>1762914946558</td></tr></tbody></table></div>

# %%
display(dbutils.fs.ls("/databricks-datasets/nyctaxi/tripdata/yellow/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz</td><td>yellow_tripdata_2009-01.csv.gz</td><td>504262564</td><td>1596568279000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-02.csv.gz</td><td>yellow_tripdata_2009-02.csv.gz</td><td>480034681</td><td>1596568279000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-03.csv.gz</td><td>yellow_tripdata_2009-03.csv.gz</td><td>521102719</td><td>1596568279000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-04.csv.gz</td><td>yellow_tripdata_2009-04.csv.gz</td><td>515435466</td><td>1596568279000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-05.csv.gz</td><td>yellow_tripdata_2009-05.csv.gz</td><td>531133739</td><td>1596568279000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-06.csv.gz</td><td>yellow_tripdata_2009-06.csv.gz</td><td>508802995</td><td>1596568313000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-07.csv.gz</td><td>yellow_tripdata_2009-07.csv.gz</td><td>487731497</td><td>1596568318000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-08.csv.gz</td><td>yellow_tripdata_2009-08.csv.gz</td><td>490825210</td><td>1596568318000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-09.csv.gz</td><td>yellow_tripdata_2009-09.csv.gz</td><td>503121179</td><td>1596568318000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-10.csv.gz</td><td>yellow_tripdata_2009-10.csv.gz</td><td>567109604</td><td>1596568319000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-11.csv.gz</td><td>yellow_tripdata_2009-11.csv.gz</td><td>520260634</td><td>1596568351000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-12.csv.gz</td><td>yellow_tripdata_2009-12.csv.gz</td><td>530726595</td><td>1596568354000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-01.csv.gz</td><td>yellow_tripdata_2010-01.csv.gz</td><td>565548417</td><td>1596568356000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-02.csv.gz</td><td>yellow_tripdata_2010-02.csv.gz</td><td>396576504</td><td>1596568357000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-03.csv.gz</td><td>yellow_tripdata_2010-03.csv.gz</td><td>456086101</td><td>1596568363000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-04.csv.gz</td><td>yellow_tripdata_2010-04.csv.gz</td><td>579400917</td><td>1596568386000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-05.csv.gz</td><td>yellow_tripdata_2010-05.csv.gz</td><td>593525883</td><td>1596568389000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-06.csv.gz</td><td>yellow_tripdata_2010-06.csv.gz</td><td>568228308</td><td>1596568393000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-07.csv.gz</td><td>yellow_tripdata_2010-07.csv.gz</td><td>562093150</td><td>1596568396000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-08.csv.gz</td><td>yellow_tripdata_2010-08.csv.gz</td><td>441394152</td><td>1596568396000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-09.csv.gz</td><td>yellow_tripdata_2010-09.csv.gz</td><td>560174405</td><td>1596568429000</td></tr><tr><td>dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2010-10.cs ...

# %%
# Read the dataset
yellow = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .csv("/databricks-datasets/nyctaxi/tripdata/yellow/*.csv.gz")
)

print("Rows:", yellow.count())
yellow.printSchema()
display(yellow.limit(5))
# Out:
# No such comm: LSP_COMM_ID
# Rows: 1611611035
# root
#  |-- vendor_id: string (nullable = true)
#  |-- pickup_datetime: string (nullable = true)
#  |-- dropoff_datetime: string (nullable = true)
#  |-- passenger_count: string (nullable = true)
#  |-- trip_distance: string (nullable = true)
#  |-- pickup_longitude: string (nullable = true)
#  |-- pickup_latitude: string (nullable = true)
#  |-- rate_code: string (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- dropoff_longitude: string (nullable = true)
#  |-- dropoff_latitude: string (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- fare_amount: string (nullable = true)
#  |-- surcharge: string (nullable = true)
#  |-- mta_tax: string (nullable = true)
#  |-- tip_amount: string (nullable = true)
#  |-- tolls_amount: string (nullable = true)
#  |-- total_amount: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>vendor_id</th><th>pickup_datetime</th><th>dropoff_datetime</th><th>passenger_count</th><th>trip_distance</th><th>pickup_longitude</th><th>pickup_latitude</th><th>rate_code</th><th>store_and_fwd_flag</th><th>dropoff_longitude</th><th>dropoff_latitude</th><th>payment_type</th><th>fare_amount</th><th>surcharge</th><th>mta_tax</th><th>tip_amount</th><th>tolls_amount</th><th>total_amount</th></tr></thead><tbody><tr><td>CMT</td><td>2010-05-28 21:09:20</td><td>2010-05-28 21:30:50</td><td>2</td><td>4.5999999999999996</td><td>-74.001684999999995</td><td>40.721344999999999</td><td>1</td><td>0</td><td>-73.958202999999997</td><td>40.769568</td><td>Cas</td><td>15.300000000000001</td><td>0.5</td><td>0.5</td><td>0</td><td>0</td><td>16.300000000000001</td></tr><tr><td>CMT</td><td>2010-05-28 15:58:09</td><td>2010-05-28 16:01:31</td><td>1</td><td>0.69999999999999996</td><td>-73.955654999999993</td><td>40.776583000000002</td><td>1</td><td>0</td><td>-73.947615999999996</td><td>40.782789999999999</td><td>Cas</td><td>4.0999999999999996</td><td>1</td><td>0.5</td><td>0</td><td>0</td><td>5.5999999999999996</td></tr><tr><td>CMT</td><td>2010-05-28 10:42:44</td><td>2010-05-28 10:46:14</td><td>1</td><td>0.40000000000000002</td><td>-73.987707999999998</td><td>40.775210000000001</td><td>1</td><td>0</td><td>-73.982101</td><td>40.775250999999997</td><td>Cas</td><td>3.7000000000000002</td><td>0</td><td>0.5</td><td>0</td><td>0</td><td>4.2000000000000002</td></tr><tr><td>CMT</td><td>2010-05-27 23:14:35</td><td>2010-05-27 23:22:23</td><td>1</td><td>2.1000000000000001</td><td>-73.972201999999996</td><td>40.755898999999999</td><td>1</td><td>0</td><td>-73.986386999999993</td><td>40.730299000000002</td><td>Cas</td><td>7.2999999999999998</td><td>0.5</td><td>0.5</td><td>0</td><td>0</td><td>8.3000000000000007</td></tr><tr><td>CMT</td><td>2010-05-28 00:10:10</td><td>2010-05-28 00:12:18</td><td>1</td><td>0.5</td><td>-73.992769999999993</td><td>40.748280999999999</td><td>1</td><td>0</td><td>-74.000422</td><td>40.747920999999998</td><td>Cas</td><td>3.7000000000000002</td><td>0.5</td><td>0.5</td><td>0</td><td>0</td><td>4.7000000000000002</td></tr></tbody></table></div>

# %%
# Inspect dataset size 
files = dbutils.fs.ls("/databricks-datasets/nyctaxi/tripdata/yellow/")
total_bytes = sum(f.size for f in files)
total_gb_compressed = total_bytes / (1024**3)
estimated_uncompressed_gb = total_gb_compressed * 4  # average ×4 expansion
print(f"Compressed size: {total_gb_compressed:.2f} GB")
print(f"Estimated uncompressed size: {estimated_uncompressed_gb:.2f} GB (≈×4 expansion)")
# Out:
# Compressed size: 46.79 GB
# Estimated uncompressed size: 187.17 GB (≈×4 expansion)

# %%
# Convert once to Parquet for much faster reloads later
yellow.write.mode("overwrite").parquet("dbfs:/tmp/nyctaxi_parquet")

# Fast reload path (use this in later sessions instead of CSV):
yellow = spark.read.parquet("dbfs:/tmp/nyctaxi_parquet")

print("Parquet converted.")
# Out:
# Parquet converted.

# %%
# Randomly keep about 5% of rows
yellow_sampled = yellow.sample(withReplacement=False, fraction=0.05, seed=42)

print("Original count:", yellow.count())
print("Sampled count:", yellow_sampled.count())
# Out:
# Original count: 1611611035
# Sampled count: 80576536

# %%
# This is about 9-10 GB. I will sample 15% again to keep ~1.5GB.
yellow_sampled_2 = yellow_sampled.sample(withReplacement=False, fraction=0.15, seed=42)
print("Sampled count:", yellow_sampled_2.count())
# Out:
# Sampled count: 12090682

# %%
# Read the taxi zone dataset
zones = (spark.read
         .option("header", True)
         .option("inferSchema", True)
         .csv("/databricks-datasets/nyctaxi/taxizone/taxi_zone_lookup.csv"))

print("Rows:", zones.count())
zones.printSchema()
display(zones.limit(5))
# Out:
# Rows: 265
# root
#  |-- LocationID: integer (nullable = true)
#  |-- Borough: string (nullable = true)
#  |-- Zone: string (nullable = true)
#  |-- service_zone: string (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>LocationID</th><th>Borough</th><th>Zone</th><th>service_zone</th></tr></thead><tbody><tr><td>1</td><td>EWR</td><td>Newark Airport</td><td>EWR</td></tr><tr><td>2</td><td>Queens</td><td>Jamaica Bay</td><td>Boro Zone</td></tr><tr><td>3</td><td>Bronx</td><td>Allerton/Pelham Gardens</td><td>Boro Zone</td></tr><tr><td>4</td><td>Manhattan</td><td>Alphabet City</td><td>Yellow Zone</td></tr><tr><td>5</td><td>Staten Island</td><td>Arden Heights</td><td>Boro Zone</td></tr></tbody></table></div>

# %%
yellow_sampled_2.columns
# Out:
# ['vendor_id',
#  'pickup_datetime',
#  'dropoff_datetime',
#  'passenger_count',
#  'trip_distance',
#  'pickup_longitude',
#  'pickup_latitude',
#  'rate_code',
#  'store_and_fwd_flag',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'payment_type',
#  'fare_amount',
#  'surcharge',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'total_amount']

# %% [markdown]
# # Apply transformations

# %%
from pyspark.sql import functions as F

pickup_col  = "pickup_datetime"
dropoff_col = "dropoff_datetime"

df = yellow_sampled_2

# Columns that should be numeric
numeric_cols = ["passenger_count","trip_distance","fare_amount","tip_amount","tolls_amount","total_amount"]

# Remove commas/whitespace/$ but KEEP e/E for scientific notation, then try_cast to double
for c in numeric_cols:
    if c in df.columns:
        df = df.withColumn(
            c,
            F.expr(f"try_cast(regexp_replace(cast({c} as string), '[, $]', '') as double)")
        )

# payment_type -> int (strip non-digits; tolerate bad rows)
if "payment_type" in df.columns:
    df = df.withColumn(
        "payment_type",
        F.expr("try_cast(regexp_replace(cast(payment_type as string), '[^0-9-]', '') as int)")
    )

# Timestamps + engineered columns
df = (df
      .withColumn("pickup_ts",  F.col(pickup_col).cast("timestamp"))
      .withColumn("dropoff_ts", F.col(dropoff_col).cast("timestamp"))
      .withColumn("pickup_date", F.to_date("pickup_ts"))
      .withColumn("pickup_hour", F.hour("pickup_ts"))
      .withColumn("trip_mins", (F.unix_timestamp("dropoff_ts") - F.unix_timestamp("pickup_ts"))/60.0)
      .withColumn("tip_pct",
                  F.when(F.col("fare_amount") > 0,
                         F.col("tip_amount") / F.col("fare_amount"))
                   .otherwise(F.lit(0.0)))
)

df.printSchema()
display(df.select("fare_amount","tip_amount","tip_pct","payment_type").limit(10))
# Out:
# root
#  |-- vendor_id: string (nullable = true)
#  |-- pickup_datetime: string (nullable = true)
#  |-- dropoff_datetime: string (nullable = true)
#  |-- passenger_count: double (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- pickup_longitude: string (nullable = true)
#  |-- pickup_latitude: string (nullable = true)
#  |-- rate_code: string (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- dropoff_longitude: string (nullable = true)
#  |-- dropoff_latitude: string (nullable = true)
#  |-- payment_type: integer (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- surcharge: string (nullable = true)
#  |-- mta_tax: string (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- pickup_ts: timestamp (nullable = true)
#  |-- dropoff_ts: timestamp (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- pickup_hour: integer (nullable = true)
#  |-- trip_mins: double (nullable = true)
#  |-- tip_pct: double (nullable = true)
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fare_amount</th><th>tip_amount</th><th>tip_pct</th><th>payment_type</th></tr></thead><tbody><tr><td>3.7</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>6.9</td><td>1.58</td><td>0.2289855072463768</td><td>null</td></tr><tr><td>13.7</td><td>2.0</td><td>0.14598540145985403</td><td>null</td></tr><tr><td>7.7</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>4.9</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>6.5</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>4.5</td><td>2.0</td><td>0.4444444444444444</td><td>null</td></tr><tr><td>8.5</td><td>1.0</td><td>0.11764705882352941</td><td>null</td></tr><tr><td>10.5</td><td>0.0</td><td>0.0</td><td>null</td></tr><tr><td>23.7</td><td>0.0</td><td>0.0</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# In the next cell, I have optimized my queries since I did filter early in my pipeline, before join and groupBy.

# %%
# 4 filter and 1 join
lookup = spark.createDataFrame(
    [(0,"Unknown/No Charge"),(1,"Credit Card"),(2,"Cash"),(3,"No Charge/Dispute"),(4,"Dispute"),(5,"Unknown")],
    ["payment_type","payment_desc"]
)
df_f = (df
        .filter(F.col("pickup_date").isNotNull())
        .filter((F.col("trip_distance") > 0) & (F.col("trip_distance") < 200))
        .filter((F.col("fare_amount") > 0) & (F.col("fare_amount") < 1000))
        .filter(F.col("trip_mins") > 0)
       )
dfj = df_f.join(lookup, on="payment_type", how="left")
display(dfj.select("pickup_date","pickup_hour","trip_distance","fare_amount","tip_pct","payment_type","payment_desc").limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_date</th><th>pickup_hour</th><th>trip_distance</th><th>fare_amount</th><th>tip_pct</th><th>payment_type</th><th>payment_desc</th></tr></thead><tbody><tr><td>2010-05-28</td><td>0</td><td>0.5</td><td>3.7</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>2010-05-24</td><td>22</td><td>1.6</td><td>6.9</td><td>0.2289855072463768</td><td>null</td><td>null</td></tr><tr><td>2010-05-30</td><td>8</td><td>4.7</td><td>13.7</td><td>0.14598540145985403</td><td>null</td><td>null</td></tr><tr><td>2010-05-12</td><td>9</td><td>1.8</td><td>7.7</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>2010-05-06</td><td>13</td><td>0.91</td><td>4.9</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>2010-05-30</td><td>19</td><td>1.19</td><td>6.5</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>2010-05-04</td><td>0</td><td>0.86</td><td>4.5</td><td>0.4444444444444444</td><td>null</td><td>null</td></tr><tr><td>2010-05-18</td><td>8</td><td>2.1</td><td>8.5</td><td>0.11764705882352941</td><td>null</td><td>null</td></tr><tr><td>2010-05-13</td><td>23</td><td>3.61</td><td>10.5</td><td>0.0</td><td>null</td><td>null</td></tr><tr><td>2010-05-12</td><td>11</td><td>9.9</td><td>23.7</td><td>0.0</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# groupBy and agg and orderBy
# Aggregation by payment method
agg_by_pay = (dfj
              .groupBy("payment_type","payment_desc")
              .agg(
                  F.count("*").alias("trips"),
                  F.avg("trip_distance").alias("avg_miles"),
                  F.avg("fare_amount").alias("avg_fare"),
                  F.avg("tip_pct").alias("avg_tip_pct"),
                  F.sum("total_amount").alias("sum_rev")
              )
              .orderBy(F.desc("trips")))
display(agg_by_pay)
agg_by_pay.explain(mode="formatted")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_type</th><th>payment_desc</th><th>trips</th><th>avg_miles</th><th>avg_fare</th><th>avg_tip_pct</th><th>sum_rev</th></tr></thead><tbody><tr><td>null</td><td>null</td><td>7690320</td><td>2.8510525594513605</td><td>10.94555247766016</td><td>0.09110438995817935</td><td>9.943179679000303E7</td></tr><tr><td>1</td><td>Credit Card</td><td>1425528</td><td>2.9228725075901676</td><td>9.774187430902794</td><td>0.3318986884136245</td><td>447613.44999967417</td></tr><tr><td>0</td><td>Unknown/No Charge</td><td>1314571</td><td>3.000520443551546</td><td>0.5000058574242092</td><td>0.5999835687838162</td><td>442375.25</td></tr><tr><td>5</td><td>Unknown</td><td>777037</td><td>2.990820244081045</td><td>0.5000036034320117</td><td>0.5999868732121657</td><td>247523.0</td></tr><tr><td>2</td><td>Cash</td><td>571342</td><td>2.699831344448684</td><td>11.943479737180184</td><td>1.2685341213578476E-5</td><td>170653.20000000668</td></tr><tr><td>25</td><td>null</td><td>100980</td><td>2.716745395127747</td><td>0.5000166369578134</td><td>0.5999821746882182</td><td>251790.0</td></tr><tr><td>3</td><td>No Charge/Dispute</td><td>57846</td><td>2.7361240189468585</td><td>1.4904327006188847</td><td>0.556104996837457</td><td>134975.8</td></tr><tr><td>35</td><td>null</td><td>32381</td><td>2.08938760384176</td><td>0.5000114264537846</td><td>0.5999814706154329</td><td>80742.5</td></tr><tr><td>45</td><td>null</td><td>10345</td><td>17.237866602223296</td><td>0.5</td><td>0.5999999999999971</td><td>4145.0</td></tr><tr><td>4</td><td>Dispute</td><td>1497</td><td>3.749899799599198</td><td>14.460126920507683</td><td>0.0</td><td>446.7000000000008</td></tr><tr><td>275</td><td>null</td><td>1117</td><td>9.903097582811103</td><td>0.5</td><td>0.5999999999999968</td><td>0.0</td></tr><tr><td>7</td><td>null</td><td>800</td><td>17.652737499999997</td><td>0.5</td><td>0.6</td><td>1952.5</td></tr><tr><td>55</td><td>null</td><td>54</td><td>10.857777777777777</td><td>0.5</td><td>0.5999999999999999</td><td>0.0</td></tr><tr><td>8</td><td>null</td><td>50</td><td>3.6754000000000002</td><td>0.5</td><td>0.036</td><td>52.5</td></tr><tr><td>13</td><td>null</td><td>19</td><td>3.263157894736842</td><td>0.5</td><td>0.0</td><td>25.0</td></tr><tr><td>18</td><td>null</td><td>13</td><td>2.8807692307692303</td><td>0.5</td><td>0.04615384615384615</td><td>17.5</td></tr><tr><td>825</td><td>null</td><td>6</td><td>10.505</td><td>0.5</td><td>0.6</td><td>0.0</td></tr><tr><td>22</td><td>null</td><td>2</td><td>2.8</td><td>0.5</td><td>0.6</td><td>null</td></tr><tr><td>454</td><td>null</td><td>2</td><td>16.9</td><td>0.5</td><td>0.6</td><td>null</td></tr><tr><td>-17</td><td>null</td><td>2</td><td>4.505000000000001</td><td>0.5</td><td>0.0</td><td>5.0</td></tr><tr><td>15</td><td>null</td><td>2</td><td>1.8099999999999998</td><td>0.5</td><td>0.6</td><td>null</td></tr><tr><td>-96</td><td>null</td><td>1</td><td>3.4</td><td>10.4</td><td>0.0</td><td>null</td></tr><tr><td>11</td><td>null</td><td>1</td><td>5.0</td><td>0.5</td><td>0.6</td><td>null</td></tr><tr><td>-2</td><td>null</td><td>1</td><td>2.33</td><td>0.5</td><td>0.6</td><td>2.5</td></tr><tr><td>215</td><td>null</td><td>1</td><td>0.7</td><td>0.5</td><td>0.6</td><td>2.5</td></tr><tr><td>-12</td><td>null</td><td>1</td><td>1.81</td><td>0.5</td><td>0.0</td><td>2.5</td></tr></tbody></table></div>
# == Physical Plan ==
# AdaptiveSparkPlan (29)
# +- == Initial Plan ==
#    ColumnarToRow (28)
#    +- PhotonResultStage (27)
#       +- PhotonSort (26)
#          +- PhotonShuffleExchangeSource (25)
#             +- PhotonShuffleMapStage (24)
#                +- PhotonShuffleExchangeSink (23)
#                   +- PhotonProject (22)
#                      +- PhotonGroupingAgg (21)
#                         +- PhotonShuffleExchangeSource (20)
#                            +- PhotonShuffleMapStage (19)
#                               +- PhotonShuffleExchangeSink (18)
#                                  +- PhotonGroupingAgg (17)
#                                     +- PhotonProject (16)
#                                        +- PhotonBroadcastHashJoin LeftOuter (15)
#                                           :- PhotonGroupingAgg (8)
#                                           :  +- PhotonProject (7)
#                                           :     +- PhotonProject (6)
#                                           :        +- PhotonFilter (5)
#                                           :           +- PhotonSample (4)
#                                           :              +- PhotonSample (3)
#                                           :                 +- PhotonRowToColumnar (2)
#                                           :                    +- Scan csv  (1)
#                                           +- PhotonShuffleExchangeSource (14)
#                                              +- PhotonShuffleMapStage (13)
#                                                 +- PhotonShuffleExchangeSink (12)
#                                                    +- PhotonFilter (11)
#                                                       +- PhotonRowToColumnar (10)
#                                                          +- LocalTableScan (9)
#
#
# (1) Scan csv
# Output [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz, ... 131 entries]
# ReadSchema: struct<pickup_datetime:string,dropoff_datetime:string,trip_distance:string,payment_type:string,fare_amount:string,tip_amount:string,total_amount:string>
#
# (2) PhotonRowToColumnar
# Input [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
#
# (3) PhotonSample
# Input [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
# Arguments: 0.0, 0.05, false
#
# (4) PhotonSample
# Input [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
# Arguments: 0.0, 0.15, false
#
# (5) PhotonFilter
# Input [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
# Arguments: ((((((((isnotnull(pickup_datetime#11117) AND isnotnull(trip_distance#11120)) AND isnotnull(fare_amount#11128)) AND isnotnull(cast(cast(pickup_datetime#11117 as timestamp) as date))) AND (try_cast(regexp_replace(trip_distance#11120, [, $], , 1) as double) > 0.0)) AND (try_cast(regexp_replace(trip_distance#11120, [, $], , 1) as double) < 200.0)) AND (try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) > 0.0)) AND (try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) < 1000.0)) AND ((cast((unix_timestamp(cast(dropoff_datetime#11118 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(cast(pickup_datetime#11117 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as double) / 60.0) > 0.0))
#
# (6) PhotonProject
# Input [7]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131, total_amount#11133]
# Arguments: [try_cast(regexp_replace(trip_distance#11120, [, $], , 1) as double) AS trip_distance#11230, try_cast(regexp_replace(payment_type#11127, [^0-9-], , 1) as int) AS payment_type#11245, try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) AS fare_amount#11233, try_cast(regexp_replace(tip_amount#11131, [, $], , 1) as double) AS tip_amount#11236, try_cast(regexp_replace(total_amount#11133, [, $], , 1) as double) AS total_amount#11242]
#
# (7) PhotonProject
# Input [5]: [trip_distance#11230, payment_type#11245, fare_amount#11233, tip_amount#11236, total_amount#11242]
# Arguments: [trip_distance#11230, payment_type#11245, fare_amount#11233, total_amount#11242, CASE WHEN (fare_amount#11233 > 0.0) THEN (tip_amount#11236 / fare_amount#11233) ELSE 0.0 END AS tip_pct#11257]
#
# (8) PhotonGroupingAgg
# Input [5]: [trip_distance#11230, payment_type#11245, fare_amount#11233, total_amount#11242, tip_pct#11257]
# Arguments: [payment_type#11245], [partial_count(1) AS count#11489L, partial_avg(trip_distance#11230) AS (sum#11492, count#11493L), partial_avg(fare_amount#11233) AS (sum#11496, count#11497L), partial_avg(tip_pct#11257) AS (sum#11500, count#11501L), partial_sum(total_amount#11242) AS sum#11503], [count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503], [payment_type#11245, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503], false
#
# (9) LocalTableScan
# Output [2]: [payment_type#11481L, payment_desc#11482]
# Arguments: [payment_type#11481L, payment_desc#11482]
#
# (10) PhotonRowToColumnar
# Input [2]: [payment_type#11481L, payment_desc#11482]
#
# (11) PhotonFilter
# Input [2]: [payment_type#11481L, payment_desc#11482]
# Arguments: isnotnull(payment_type#11481L)
#
# (12) PhotonShuffleExchangeSink
# Input [2]: [payment_type#11481L, payment_desc#11482]
# Arguments: SinglePartition
#
# (13) PhotonShuffleMapStage
# Input [2]: [payment_type#11481L, payment_desc#11482]
# Arguments: EXECUTOR_BROADCAST, [id=#9364]
#
# (14) PhotonShuffleExchangeSource
# Input [2]: [payment_type#11481L, payment_desc#11482]
#
# (15) PhotonBroadcastHashJoin
# Left keys [1]: [cast(payment_type#11245 as bigint)]
# Right keys [1]: [payment_type#11481L]
# Join type: LeftOuter
# Join condition: None
#
# (16) PhotonProject
# Input [11]: [payment_type#11245, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503, payment_type#11481L, payment_desc#11482]
# Arguments: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
#
# (17) PhotonGroupingAgg
# Input [10]: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
# Arguments: [payment_type#11245, payment_desc#11482], [merge_count(merge count#11489L) AS count#11489L, merge_avg(merge sum#11492, count#11493L) AS (sum#11492, count#11493L), merge_avg(merge sum#11496, count#11497L) AS (sum#11496, count#11497L), merge_avg(merge sum#11500, count#11501L) AS (sum#11500, count#11501L), merge_sum(merge sum#11503) AS sum#11503], [count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503], [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503], false
#
# (18) PhotonShuffleExchangeSink
# Input [10]: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
# Arguments: hashpartitioning(payment_type#11245, payment_desc#11482, 1024)
#
# (19) PhotonShuffleMapStage
# Input [10]: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
# Arguments: ENSURE_REQUIREMENTS, [id=#9373]
#
# (20) PhotonShuffleExchangeSource
# Input [10]: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
#
# (21) PhotonGroupingAgg
# Input [10]: [payment_type#11245, payment_desc#11482, count#11489L, sum#11492, count#11493L, sum#11496, count#11497L, sum#11500, count#11501L, sum#11503]
# Arguments: [payment_type#11245, payment_desc#11482], [finalmerge_count(merge count#11489L) AS count(1)#11483L, finalmerge_avg(merge sum#11492, count#11493L) AS avg(trip_distance)#11484, finalmerge_avg(merge sum#11496, count#11497L) AS avg(fare_amount)#11485, finalmerge_avg(merge sum#11500, count#11501L) AS avg(tip_pct)#11486, finalmerge_sum(merge sum#11503) AS sum(total_amount)#11487], [count(1)#11483L, avg(trip_distance)#11484, avg(fare_amount)#11485, avg(tip_pct)#11486, sum(total_amount)#11487], [payment_type#11245, payment_desc#11482, count(1)#11483L, avg(trip_distance)#11484, avg(fare_amount)#11485, avg(tip_pct)#11486, sum(total_amount)#11487], true
#
# (22) PhotonProject
# Input [7]: [payment_type#11245, payment_desc#11482, count(1)#11483L, avg(trip_distance)#11484, avg(fare_amount)#11485, avg(tip_pct)#11486, sum(total_amount)#11487]
# Arguments: [payment_type#11245, payment_desc#11482, count(1)#11483L AS trips#11300L, avg(trip_distance)#11484 AS avg_miles#11301, avg(fare_amount)#11485 AS avg_fare#11302, avg(tip_pct)#11486 AS avg_tip_pct#11303, sum(total_amount)#11487 AS sum_rev#11304]
#
# (23) PhotonShuffleExchangeSink
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
# Arguments: rangepartitioning(trips#11300L DESC NULLS LAST, 1024)
#
# (24) PhotonShuffleMapStage
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
# Arguments: ENSURE_REQUIREMENTS, [id=#9381]
#
# (25) PhotonShuffleExchangeSource
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
#
# (26) PhotonSort
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
# Arguments: [trips#11300L DESC NULLS LAST]
#
# (27) PhotonResultStage
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
#
# (28) ColumnarToRow
# Input [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
#
# (29) AdaptiveSparkPlan
# Output [7]: [payment_type#11245, payment_desc#11482, trips#11300L, avg_miles#11301, avg_fare#11302, avg_tip_pct#11303, sum_rev#11304]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# groupBy and agg and orderBY
# Aggregation by daily profile
daily = (dfj
         .groupBy("pickup_date")
         .agg(
             F.count("*").alias("trips"),
             F.avg("trip_mins").alias("avg_trip_mins"),
             F.avg("tip_pct").alias("avg_tip_pct")
         )
         .orderBy("pickup_date"))
display(daily.limit(20))
daily.explain(mode="formatted")
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_date</th><th>trips</th><th>avg_trip_mins</th><th>avg_tip_pct</th></tr></thead><tbody><tr><td>2008-12-31</td><td>5</td><td>24.020000000000003</td><td>0.6</td></tr><tr><td>2009-01-01</td><td>2398</td><td>10.878343063664136</td><td>0.030839609305697423</td></tr><tr><td>2009-01-02</td><td>2808</td><td>11.85220797720797</td><td>0.03168027412460632</td></tr><tr><td>2009-01-03</td><td>3128</td><td>11.219698422847404</td><td>0.03270335970419716</td></tr><tr><td>2009-01-04</td><td>2625</td><td>12.030539682539674</td><td>0.03932234868673462</td></tr><tr><td>2009-01-05</td><td>2684</td><td>11.893541977148542</td><td>0.03692311857892215</td></tr><tr><td>2009-01-06</td><td>3177</td><td>12.096742209631744</td><td>0.03943938531739688</td></tr><tr><td>2009-01-07</td><td>2637</td><td>12.506648969788907</td><td>0.04501258736211092</td></tr><tr><td>2009-01-08</td><td>3517</td><td>12.09092029191547</td><td>0.042479770664184964</td></tr><tr><td>2009-01-09</td><td>3831</td><td>13.734803793613521</td><td>0.041467389969206875</td></tr><tr><td>2009-01-10</td><td>3436</td><td>11.894732246798615</td><td>0.03639830066208607</td></tr><tr><td>2009-01-11</td><td>2919</td><td>12.573552586502233</td><td>0.042152622773116655</td></tr><tr><td>2009-01-12</td><td>3030</td><td>12.59525852585255</td><td>0.042932277076011056</td></tr><tr><td>2009-01-13</td><td>3290</td><td>12.162142857142836</td><td>0.04472308868909637</td></tr><tr><td>2009-01-14</td><td>3696</td><td>11.50889249639246</td><td>0.04496446188290816</td></tr><tr><td>2009-01-15</td><td>3551</td><td>12.672707218623854</td><td>0.04785097960912132</td></tr><tr><td>2009-01-16</td><td>3819</td><td>11.881718599982545</td><td>0.04566580415712386</td></tr><tr><td>2009-01-17</td><td>3664</td><td>11.956682132459965</td><td>0.03816205403145454</td></tr><tr><td>2009-01-18</td><td>3061</td><td>10.704257867799193</td><td>0.04033043376950861</td></tr><tr><td>2009-01-19</td><td>2640</td><td>12.636060606060589</td><td>0.043453245147939815</td></tr></tbody></table></div>
# == Physical Plan ==
# AdaptiveSparkPlan (27)
# +- == Initial Plan ==
#    ColumnarToRow (26)
#    +- PhotonResultStage (25)
#       +- PhotonSort (24)
#          +- PhotonShuffleExchangeSource (23)
#             +- PhotonShuffleMapStage (22)
#                +- PhotonShuffleExchangeSink (21)
#                   +- PhotonGroupingAgg (20)
#                      +- PhotonShuffleExchangeSource (19)
#                         +- PhotonShuffleMapStage (18)
#                            +- PhotonShuffleExchangeSink (17)
#                               +- PhotonGroupingAgg (16)
#                                  +- PhotonProject (15)
#                                     +- PhotonBroadcastHashJoin LeftOuter (14)
#                                        :- PhotonProject (7)
#                                        :  +- PhotonProject (6)
#                                        :     +- PhotonFilter (5)
#                                        :        +- PhotonSample (4)
#                                        :           +- PhotonSample (3)
#                                        :              +- PhotonRowToColumnar (2)
#                                        :                 +- Scan csv  (1)
#                                        +- PhotonShuffleExchangeSource (13)
#                                           +- PhotonShuffleMapStage (12)
#                                              +- PhotonShuffleExchangeSink (11)
#                                                 +- PhotonFilter (10)
#                                                    +- PhotonRowToColumnar (9)
#                                                       +- LocalTableScan (8)
#
#
# (1) Scan csv
# Output [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
# Batched: false
# Location: InMemoryFileIndex [dbfs:/databricks-datasets/nyctaxi/tripdata/yellow/yellow_tripdata_2009-01.csv.gz, ... 131 entries]
# ReadSchema: struct<pickup_datetime:string,dropoff_datetime:string,trip_distance:string,payment_type:string,fare_amount:string,tip_amount:string>
#
# (2) PhotonRowToColumnar
# Input [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
#
# (3) PhotonSample
# Input [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
# Arguments: 0.0, 0.05, false
#
# (4) PhotonSample
# Input [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
# Arguments: 0.0, 0.15, false
#
# (5) PhotonFilter
# Input [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
# Arguments: ((((((((isnotnull(pickup_datetime#11117) AND isnotnull(trip_distance#11120)) AND isnotnull(fare_amount#11128)) AND isnotnull(cast(cast(pickup_datetime#11117 as timestamp) as date))) AND (try_cast(regexp_replace(trip_distance#11120, [, $], , 1) as double) > 0.0)) AND (try_cast(regexp_replace(trip_distance#11120, [, $], , 1) as double) < 200.0)) AND (try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) > 0.0)) AND (try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) < 1000.0)) AND ((cast((unix_timestamp(cast(dropoff_datetime#11118 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(cast(pickup_datetime#11117 as timestamp), yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as double) / 60.0) > 0.0))
#
# (6) PhotonProject
# Input [6]: [pickup_datetime#11117, dropoff_datetime#11118, trip_distance#11120, payment_type#11127, fare_amount#11128, tip_amount#11131]
# Arguments: [try_cast(regexp_replace(payment_type#11127, [^0-9-], , 1) as int) AS payment_type#11245, try_cast(regexp_replace(fare_amount#11128, [, $], , 1) as double) AS fare_amount#11233, try_cast(regexp_replace(tip_amount#11131, [, $], , 1) as double) AS tip_amount#11236, cast(pickup_datetime#11117 as timestamp) AS pickup_ts#11247, cast(dropoff_datetime#11118 as timestamp) AS dropoff_ts#11249]
#
# (7) PhotonProject
# Input [5]: [payment_type#11245, fare_amount#11233, tip_amount#11236, pickup_ts#11247, dropoff_ts#11249]
# Arguments: [payment_type#11245, cast(pickup_ts#11247 as date) AS pickup_date#11251, (cast((unix_timestamp(dropoff_ts#11249, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true) - unix_timestamp(pickup_ts#11247, yyyy-MM-dd HH:mm:ss, Some(Etc/UTC), true)) as double) / 60.0) AS trip_mins#11255, CASE WHEN (fare_amount#11233 > 0.0) THEN (tip_amount#11236 / fare_amount#11233) ELSE 0.0 END AS tip_pct#11257]
#
# (8) LocalTableScan
# Output [1]: [payment_type#11684L]
# Arguments: [payment_type#11684L]
#
# (9) PhotonRowToColumnar
# Input [1]: [payment_type#11684L]
#
# (10) PhotonFilter
# Input [1]: [payment_type#11684L]
# Arguments: isnotnull(payment_type#11684L)
#
# (11) PhotonShuffleExchangeSink
# Input [1]: [payment_type#11684L]
# Arguments: SinglePartition
#
# (12) PhotonShuffleMapStage
# Input [1]: [payment_type#11684L]
# Arguments: EXECUTOR_BROADCAST, [id=#10152]
#
# (13) PhotonShuffleExchangeSource
# Input [1]: [payment_type#11684L]
#
# (14) PhotonBroadcastHashJoin
# Left keys [1]: [cast(payment_type#11245 as bigint)]
# Right keys [1]: [payment_type#11684L]
# Join type: LeftOuter
# Join condition: None
#
# (15) PhotonProject
# Input [5]: [payment_type#11245, pickup_date#11251, trip_mins#11255, tip_pct#11257, payment_type#11684L]
# Arguments: [pickup_date#11251, trip_mins#11255, tip_pct#11257]
#
# (16) PhotonGroupingAgg
# Input [3]: [pickup_date#11251, trip_mins#11255, tip_pct#11257]
# Arguments: [pickup_date#11251], [partial_count(1) AS count#11690L, partial_avg(trip_mins#11255) AS (sum#11693, count#11694L), partial_avg(tip_pct#11257) AS (sum#11697, count#11698L)], [count#11689L, sum#11691, count#11692L, sum#11695, count#11696L], [pickup_date#11251, count#11690L, sum#11693, count#11694L, sum#11697, count#11698L], false
#
# (17) PhotonShuffleExchangeSink
# Input [6]: [pickup_date#11251, count#11690L, sum#11693, count#11694L, sum#11697, count#11698L]
# Arguments: hashpartitioning(pickup_date#11251, 1024)
#
# (18) PhotonShuffleMapStage
# Input [6]: [pickup_date#11251, count#11690L, sum#11693, count#11694L, sum#11697, count#11698L]
# Arguments: ENSURE_REQUIREMENTS, [id=#10161]
#
# (19) PhotonShuffleExchangeSource
# Input [6]: [pickup_date#11251, count#11690L, sum#11693, count#11694L, sum#11697, count#11698L]
#
# (20) PhotonGroupingAgg
# Input [6]: [pickup_date#11251, count#11690L, sum#11693, count#11694L, sum#11697, count#11698L]
# Arguments: [pickup_date#11251], [finalmerge_count(merge count#11690L) AS count(1)#11686L, finalmerge_avg(merge sum#11693, count#11694L) AS avg(trip_mins)#11687, finalmerge_avg(merge sum#11697, count#11698L) AS avg(tip_pct)#11688], [count(1)#11686L, avg(trip_mins)#11687, avg(tip_pct)#11688], [pickup_date#11251, count(1)#11686L AS trips#11681L, avg(trip_mins)#11687 AS avg_trip_mins#11682, avg(tip_pct)#11688 AS avg_tip_pct#11683], true
#
# (21) PhotonShuffleExchangeSink
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
# Arguments: rangepartitioning(pickup_date#11251 ASC NULLS FIRST, 1024)
#
# (22) PhotonShuffleMapStage
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
# Arguments: ENSURE_REQUIREMENTS, [id=#10167]
#
# (23) PhotonShuffleExchangeSource
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
#
# (24) PhotonSort
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
# Arguments: [pickup_date#11251 ASC NULLS FIRST]
#
# (25) PhotonResultStage
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
#
# (26) ColumnarToRow
# Input [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
#
# (27) AdaptiveSparkPlan
# Output [4]: [pickup_date#11251, trips#11681L, avg_trip_mins#11682, avg_tip_pct#11683]
# Arguments: isFinalPlan=false
#
#
# == Photon Explanation ==
# The query is fully supported by Photon.

# %%
# SQL views
dfj.createOrReplaceTempView("trips")
agg_by_pay.createOrReplaceTempView("agg_by_pay")
daily.createOrReplaceTempView("daily_trips")

# %%
# SQL #1: Top payment types by avg tip pct (with volume threshold)
display(spark.sql("""
SELECT payment_desc, trips, avg_tip_pct
FROM agg_by_pay
WHERE trips > 20000
ORDER BY avg_tip_pct DESC
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>payment_desc</th><th>trips</th><th>avg_tip_pct</th></tr></thead><tbody><tr><td>null</td><td>32832</td><td>0.5999999999999873</td></tr><tr><td>null</td><td>101125</td><td>0.5999940667492517</td></tr><tr><td>Unknown/No Charge</td><td>1315150</td><td>0.5999881382344024</td></tr><tr><td>Unknown</td><td>776747</td><td>0.5999814611446724</td></tr><tr><td>No Charge/Dispute</td><td>58069</td><td>0.5562115698059619</td></tr><tr><td>Credit Card</td><td>1424833</td><td>0.3317679149043738</td></tr><tr><td>null</td><td>7690320</td><td>0.09110438995817935</td></tr><tr><td>Cash</td><td>571338</td><td>8.484764219513413E-6</td></tr></tbody></table></div>

# %%
# SQL #2: Hourly profile for longer trips
display(spark.sql("""
SELECT pickup_hour, COUNT(*) AS trips, AVG(trip_distance) AS avg_miles, AVG(tip_pct) AS avg_tip_pct
FROM trips
WHERE trip_distance >= 10
GROUP BY pickup_hour
ORDER BY pickup_hour
"""))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_hour</th><th>trips</th><th>avg_miles</th><th>avg_tip_pct</th></tr></thead><tbody><tr><td>0</td><td>20887</td><td>14.702872121415234</td><td>0.229362961292806</td></tr><tr><td>1</td><td>13117</td><td>14.25104139666082</td><td>0.2095982222293419</td></tr><tr><td>2</td><td>9208</td><td>13.742932232841008</td><td>0.18901367087533566</td></tr><tr><td>3</td><td>8370</td><td>13.87738470728793</td><td>0.173694811091896</td></tr><tr><td>4</td><td>11496</td><td>14.09176409185804</td><td>0.20053119700513564</td></tr><tr><td>5</td><td>16433</td><td>15.34563682833323</td><td>0.23427137247977375</td></tr><tr><td>6</td><td>21970</td><td>15.601621756941285</td><td>0.239391892633447</td></tr><tr><td>7</td><td>23570</td><td>15.166803563852355</td><td>0.24013893596040872</td></tr><tr><td>8</td><td>23357</td><td>14.649639508498526</td><td>0.236913664080508</td></tr><tr><td>9</td><td>23381</td><td>14.226450536760616</td><td>0.24009947619837888</td></tr><tr><td>10</td><td>24263</td><td>14.13435807608292</td><td>0.24046933222658673</td></tr><tr><td>11</td><td>26445</td><td>14.42086254490452</td><td>0.23279157541098255</td></tr><tr><td>12</td><td>28693</td><td>14.570177046666437</td><td>0.23776227009583983</td></tr><tr><td>13</td><td>33778</td><td>15.056641601042093</td><td>0.23693188589812827</td></tr><tr><td>14</td><td>38904</td><td>15.254383610939744</td><td>0.2370714376127393</td></tr><tr><td>15</td><td>37866</td><td>15.246898536946068</td><td>0.23367791377728145</td></tr><tr><td>16</td><td>34013</td><td>15.265583747390705</td><td>0.2467857426657488</td></tr><tr><td>17</td><td>32560</td><td>15.254426904176903</td><td>0.24653118514928016</td></tr><tr><td>18</td><td>29110</td><td>15.17800137409825</td><td>0.8306690122805995</td></tr><tr><td>19</td><td>27412</td><td>15.211185247336939</td><td>0.24722085764296917</td></tr><tr><td>20</td><td>28962</td><td>15.196098681030314</td><td>0.25248033845275264</td></tr><tr><td>21</td><td>30225</td><td>14.937724731182799</td><td>0.25044403954276306</td></tr><tr><td>22</td><td>29718</td><td>14.771918029477089</td><td>0.24226212328240665</td></tr><tr><td>23</td><td>27621</td><td>14.645045436443292</td><td>0.2393777127063879</td></tr></tbody></table></div>

# %% [markdown]
# ## PySpark Optimization (Faster)

# %%
# PySpark performance on ~1GB (mimics your screenshot)
from pyspark.sql.functions import col, desc
import time

# Choose a reasonably wide/probing selection to make the grouping meaningful
df_large = (dfj
    .select("payment_desc", "pickup_hour", "trip_distance", "fare_amount", "tip_pct")
    .filter((col("fare_amount") > 0) & (col("trip_distance") > 0))
)
_ = df_large.count()  # materialize cache so we're timing the actual aggregation work

start = time.time()

result_large = (df_large
    .filter(col("tip_pct") > 0)     # analogous to delay > 0
    .groupBy("payment_desc")        # analogous to groupBy('origin')
    .count()
    .orderBy(desc("count"))
    .limit(10)
)

result_large.show(truncate=False)

large_time = time.time() - start

print(f"\n⏱️  PySpark on ~1GB sample: {large_time:.2f} seconds")
print(f"\n💡 Pandas would:")
print(f"  - Often take 3–5× longer (~{large_time*4:.1f}s estimate) on the same machine")
print( "  - Or risk MemoryError if the dataset doesn't fit driver RAM")
print("\n✅ PySpark distributes the work across the cluster and handles it smoothly.")
# Out:
# +-----------------+-------+
# |payment_desc     |count  |
# +-----------------+-------+
# |NULL             |3465266|
# |Credit Card      |1387827|
# |Unknown/No Charge|1315124|
# |Unknown          |776723 |
# |No Charge/Dispute|53833  |
# |Cash             |15     |
# +-----------------+-------+
#
#
# ⏱️  PySpark on ~1GB sample: 498.74 seconds
#
# 💡 Pandas would:
#   - Often take 3–5× longer (~1994.9s estimate) on the same machine
#   - Or risk MemoryError if the dataset doesn't fit driver RAM
#
# ✅ PySpark distributes the work across the cluster and handles it smoothly.

# %% [markdown]
# ## Write results to Parquet

# %%
# Save results to Parquet
dfj.write.mode("overwrite").parquet("dbfs:/tmp/nyc_taxi_results")

print("Parquet converted.")
# Out:
# Parquet converted.

# %% [markdown]
# # Actions vs Transformations

# %% [markdown]
# ## Lazy Evaluation

# %%
# Lazy Evaluation (using NYC Taxi df)

query = (
    dfj
    .select("pickup_date", "fare_amount", "tip_amount", "trip_distance", "tip_pct")
    # Intentionally compute a column BEFORE filtering (wasteful by design)
    .withColumn(
        "tip_category",
        F.when(F.col("tip_pct") >= 0.3, "high") \
         .when(F.col("tip_pct") >= 0.15, "medium") \
         .otherwise("low")
    )
    # Filters written AFTER withColumn (optimizer may fix it, but this shows the idea)
    .filter(F.col("fare_amount") > 50)           # expensive to do late
    .filter(F.col("trip_distance") > 3)          # expensive to do late
    .groupBy("tip_category")
    .agg(
        F.avg("fare_amount").alias("avg_fare"),
        F.avg("trip_distance").alias("avg_miles"),
        F.count("*").alias("count")
    )
    .orderBy(F.desc("count"))
)

# Nothing has run yet. The next line is the ACTION that triggers execution.
display(query)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tip_category</th><th>avg_fare</th><th>avg_miles</th><th>count</th></tr></thead><tbody><tr><td>low</td><td>56.82622975947818</td><td>18.6201293110477</td><td>61325</td></tr><tr><td>medium</td><td>55.33771971077538</td><td>18.26595105128054</td><td>51033</td></tr><tr><td>high</td><td>58.0821972711768</td><td>18.642930642410455</td><td>3518</td></tr></tbody></table></div>

# %% [markdown]
# ## Actions vs Transformations

# %%
# Actions vs Transformations

# Transformations only (build a plan)
start = time.time()
filtered = df.filter((col("fare_amount") > 100) & (col("trip_distance") > 5))
selected = filtered.select("pickup_date", "fare_amount", "trip_distance", "tip_pct")
print(f"🧱 Transformations (plan built only), took {time.time() - start:.4f}s")

# Action 1: triggers execution
print("\n⚡ Action 1: count()")
start = time.time()
cnt = selected.count()  # ACTION
print(f"count() => {cnt:,} rows, took {time.time() - start:.2f}s")

# Action 2: triggers execution again (recomputes the plan)
print("\n⚡ Action 2: show(5)")
start = time.time()
selected.show(5, truncate=False)  # ACTION
print(f"show(5) took {time.time() - start:.2f}s")

print("\n🔁 Notice: each ACTION re-executes the upstream transformations!")
# Out:
# 🧱 Transformations (plan built only), took 0.0005s
#
# ⚡ Action 1: count()
# count() => 1,860 rows, took 452.86s
#
# ⚡ Action 2: show(5)
# +-----------+-----------+-------------+-------------------+
# |pickup_date|fare_amount|trip_distance|tip_pct            |
# +-----------+-----------+-------------+-------------------+
# |2010-05-31 |114.0      |49.7         |0.15789473684210525|
# |2010-05-01 |120.0      |19.1         |0.0                |
# |2010-05-08 |118.0      |32.2         |0.0847457627118644 |
# |2010-05-04 |100.9      |30.4         |0.0                |
# |2010-05-23 |146.25     |32.73        |0.10256410256410256|
# +-----------+-----------+-------------+-------------------+
# only showing top 5 rows
# show(5) took 30.15s
#
# 🔁 Notice: each ACTION re-executes the upstream transformations!

# %% [markdown]
# # Optional Machine Learning

# %%
# Pick the most feature-rich DataFrame available
try:
    source_df = dfj
except NameError:
    source_df = df

from pyspark.sql import functions as F

# Required columns (adjust if any are missing in your schema)
needed = ["fare_amount","tip_amount","trip_distance","passenger_count","pickup_hour","payment_type","tip_pct"]
have = [c for c in needed if c in source_df.columns]

ml = (source_df
      .select(*have)
      .na.drop(subset=["fare_amount","tip_amount","trip_distance","passenger_count"])
      .filter((F.col("fare_amount") > 0) & (F.col("trip_distance") > 0))
      .withColumn("passenger_count", F.coalesce(F.col("passenger_count").cast("double"), F.lit(1.0)))
     )

print("Rows for ML after cleaning:", ml.count())
display(ml.limit(5))
# Out:
# Rows for ML after cleaning: 11982701
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fare_amount</th><th>tip_amount</th><th>trip_distance</th><th>passenger_count</th><th>pickup_hour</th><th>payment_type</th><th>tip_pct</th></tr></thead><tbody><tr><td>3.7</td><td>0.0</td><td>0.5</td><td>1.0</td><td>0</td><td>null</td><td>0.0</td></tr><tr><td>6.9</td><td>1.58</td><td>1.6</td><td>1.0</td><td>22</td><td>null</td><td>0.2289855072463768</td></tr><tr><td>13.7</td><td>2.0</td><td>4.7</td><td>4.0</td><td>8</td><td>null</td><td>0.14598540145985403</td></tr><tr><td>7.7</td><td>0.0</td><td>1.8</td><td>5.0</td><td>9</td><td>null</td><td>0.0</td></tr><tr><td>4.9</td><td>0.0</td><td>0.91</td><td>1.0</td><td>13</td><td>null</td><td>0.0</td></tr></tbody></table></div>

# %%
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.ml.regression import LinearRegression, GBTRegressor
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator

# Categorical: payment_type (if present)
stages = []
if "payment_type" in ml.columns:
    idx = StringIndexer(inputCol="payment_type", outputCol="payment_type_idx", handleInvalid="keep")
    ohe = OneHotEncoder(inputCols=["payment_type_idx"], outputCols=["payment_type_ohe"])
    stages += [idx, ohe]
    cat_cols = ["payment_type_ohe"]
else:
    cat_cols = []

num_cols = [c for c in ["fare_amount","trip_distance","passenger_count","pickup_hour"] if c in ml.columns]

assembler = VectorAssembler(inputCols=cat_cols + num_cols, outputCol="features_raw")
scaler = StandardScaler(inputCol="features_raw", outputCol="features", withMean=False, withStd=True)

# Try a simple Linear Regression first; you can switch to GBT below
lr = LinearRegression(featuresCol="features", labelCol="tip_amount", maxIter=50, regParam=0.1, elasticNetParam=0.2)

pipeline = Pipeline(stages=stages + [assembler, scaler, lr])

train, test = ml.randomSplit([0.8, 0.2], seed=42)
model = pipeline.fit(train)
pred = model.transform(test)

for metric in ["rmse","mae","r2"]:
    ev = RegressionEvaluator(labelCol="tip_amount", predictionCol="prediction", metricName=metric)
    print(f"{metric.upper():<4}:", ev.evaluate(pred))

display(pred.select("fare_amount","trip_distance","passenger_count","tip_amount","prediction").limit(20))
# Out:
# RMSE: 1.4246476555839174
# MAE : 0.8725577183641957
# R2  : 0.35764034121529475
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>fare_amount</th><th>trip_distance</th><th>passenger_count</th><th>tip_amount</th><th>prediction</th></tr></thead><tbody><tr><td>2.5</td><td>0.01</td><td>4.0</td><td>0.0</td><td>0.18606032657937221</td></tr><tr><td>2.5</td><td>0.02</td><td>1.0</td><td>0.0</td><td>0.19447055582547101</td></tr><tr><td>2.5</td><td>0.02</td><td>3.0</td><td>0.0</td><td>0.1889574758468454</td></tr><tr><td>2.5</td><td>0.04</td><td>1.0</td><td>0.0</td><td>0.19475177438179175</td></tr><tr><td>2.5</td><td>0.04</td><td>1.0</td><td>0.0</td><td>0.19475177438179175</td></tr><tr><td>2.5</td><td>0.04</td><td>1.0</td><td>0.0</td><td>0.19475177438179175</td></tr><tr><td>2.5</td><td>0.04</td><td>1.0</td><td>0.0</td><td>0.19475177438179175</td></tr><tr><td>2.5</td><td>0.05</td><td>1.0</td><td>0.0</td><td>0.1948923836599521</td></tr><tr><td>2.5</td><td>0.05</td><td>5.0</td><td>0.0</td><td>0.18386622370270084</td></tr><tr><td>2.5</td><td>0.06</td><td>5.0</td><td>0.0</td><td>0.18400683298086118</td></tr><tr><td>2.5</td><td>0.08</td><td>2.0</td><td>0.0</td><td>0.19255767150512032</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>1.0</td><td>0.0</td><td>0.19559543005075386</td></tr><tr><td>2.5</td><td>0.1</td><td>3.0</td><td>0.0</td><td>0.19008235007212826</td></tr><tr><td>2.5</td><td>0.12</td><td>2.0</td><td>0.0</td><td>0.19312010861776174</td></tr><tr><td>2.5</td><td>0.13</td><td>1.0</td><td>0.0</td><td>0.19601725788523489</td></tr></tbody></table></div>
